# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('/kaggle/input/datasets/chauhanrovin/sales-data-cleaning-dataset/dataset.csv')

# Show data
print("First rows:")
print(df.head())

# Data info
print("\nInfo:")
print(df.info())

# Fill missing values
df['Sales'] = df['Sales'].fillna(df['Sales'].mean())


## ANALYSIS PART

# Total sales
total_sales = df['Sales'].sum()
print("\nTotal Sales:", total_sales)

# Average sales
avg_sales = df['Sales'].mean()
print("Average Sales:", avg_sales)

# Top product
top_product = df.groupby('Product')['Sales'].sum().idxmax()
print("Top Product:", top_product)

# Sales by product
sales_by_product = df.groupby('Product')['Sales'].sum()
print("\nSales by Product:")
print(sales_by_product)


## VISUALIZATION


# Bar chart
sales_by_product.plot(kind='bar')
plt.title("Sales by Product")
plt.xlabel("Product")
plt.ylabel("Total Sales")
plt.show()

# Pie chart
sales_by_product.plot(kind='pie', autopct='%1.1f%%')
plt.title("Sales Distribution")
plt.ylabel("")
plt.show()
# Out:
# First rows:
#    OrderID     Product     Category    Sales  Quantity        Date
# 0     1001      Laptop  Electronics  50000.0         1  2023-01-01
# 1     1002       Phone  Electronics      NaN         2  2023-01-02
# 2     1003      Tablet  Electronics  30000.0         1  2023-01-03
# 3     1004  Headphones  Accessories   2000.0         3  2023-01-04
# 4     1005      Laptop  Electronics  50000.0         1  2023-01-05
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OrderID   7 non-null      int64
#  1   Product   7 non-null      object
#  2   Category  7 non-null      object
#  3   Sales     5 non-null      float64
#  4   Quantity  7 non-null      int64
#  5   Date      7 non-null      object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 468.0+ bytes
# None
#
# Total Sales: 254800.0
# Average Sales: 36400.0
# Top Product: Laptop
#
# Sales by Product:
# Product
# Headphones      2000.0
# Laptop        150000.0
# Mouse          36400.0
# Phone          36400.0
# Tablet         30000.0
# Name: Sales, dtype: float64
